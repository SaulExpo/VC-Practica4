# %% [markdown]
# #Paquetes necesarios

# %%
import cv2  
import math 
import easyocr
import pytesseract
import time
import csv
import os
import csv
import torch
from ultralytics import YOLO

# %%
torch.cuda.empty_cache()

model = YOLO('yolo11s.pt') 

model.train(
    data='dataset/data.yaml',
    epochs=50,
    imgsz=960,
    batch=4,
    name='matriculas_yolo_v2',
    device='cuda',
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=5, 
    translate=0.10,
    scale=0.6,  
    shear=2.0,
    flipud=0.3,
    mixup=0.1,
    mosaic=1.0, 
)


torch.cuda.empty_cache()

model = YOLO('runs/detect/matriculas_yolo_v2/weights/best.pt')

model.train(
    data='dataset/data.yaml',
    epochs=20,
    imgsz=960,
    batch=2,  
    device='cuda',
    mosaic=0.0,  
    mixup=0.0,
    degrees=0,
    translate=0.05,
    scale=0.4,
    shear=0,
    flipud=0.1,
    name='matriculas_yolo_v2_finetuned'
)

# %%
# ----------------- CARGA DE LOS MODELOS -----------------
model_objects = YOLO('yolo11s.pt')  # personas/vehículos (COCO)
model_plates  = YOLO('runs/detect/matriculas_yolo_v2_finetuned/weights/best.pt')

# ------------------ CARGA DE LOS OCR -------------------
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
easy = easyocr.Reader(['es','en'], gpu=True)

# ----------------- PREPARAR EL VIDEO -----------------
cap = cv2.VideoCapture("video_matriculas.mp4")
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(
    "resultado_final.mp4", fourcc, 30,
    (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
)

# ----------------- PREPARAR CSV -----------------
csv_file = open("detecciones_tracking.csv", "w", newline="", encoding="utf-8")
writer = csv.writer(csv_file)
writer.writerow([
    "frame","tipo_objeto","conf","track_id","x1","y1","x2","y2",
    "conf_matricula","mx1","my1","mx2","my2","texto_matricula"
])

# ----------------- CONTEO POR ID -----------------
CLASSES_CONTAR = {"person","car","truck","motorcycle","bus"}
seen_ids = {c:set() for c in CLASSES_CONTAR}  
counts    = {c:0 for c in CLASSES_CONTAR} 

COLORS = {
    "person": (255, 0, 0),
    "car": (0, 255, 0),
    "truck": (255, 0, 255),
    "bus": (0, 255, 255),
    "motorcycle": (0, 128, 255)
}

next_id = {c: 0 for c in CLASSES_CONTAR}
class_track_ids = {}  


# ----------------- PROCESAR EL VIDEO FRAME A FRAME -----------------
frame_n = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model_objects.track(
        frame, conf=0.35, iou=0.45, tracker="bytetrack.yaml", persist=True
    )

    if results[0].boxes.id is None:
        y = 30
        for k in ["person","car","truck","motorcycle","bus"]:
            cv2.putText(frame, f"{k}: {counts[k]}", (10, y),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,255,0), 2)
            y += 28
        out.write(frame)
        frame_n += 1
        continue

    boxes  = results[0].boxes.xyxy.cpu().numpy()
    ids    = results[0].boxes.id.cpu().numpy()
    confs  = results[0].boxes.conf.cpu().numpy()
    classes= results[0].boxes.cls.cpu().numpy()

    for box, track_id, conf, cls in zip(boxes, ids, confs, classes):
        cls_name = model_objects.model.names[int(cls)]
        if cls_name not in CLASSES_CONTAR:
            continue

        x1,y1,x2,y2 = map(int, box)

        # ---------- CONTEO ÚNICO ----------
        if int(track_id) not in seen_ids[cls_name]:
            seen_ids[cls_name].add(int(track_id))
            counts[cls_name] += 1
        
        orig_id = int(track_id)
        key = (cls_name, orig_id)

        if key not in class_track_ids:
            class_track_ids[key] = f"{cls_name[0].upper()}-{next_id[cls_name]}"
            next_id[cls_name] += 1

        disp_id = class_track_ids[key]

        # ---------- DIBUJAR CUADRADOS ----------
        color = COLORS[cls_name]
        cv2.rectangle(frame, (x1,y1), (x2,y2), color, 2)
        cv2.putText(frame, f"{cls_name} {disp_id} {conf:.2f}", 
                    (x1, max(20, y1-6)), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        if cls_name == "person":
            face_h = int((y2 - y1) * 0.35)  # parte superior del cuerpo
            face_region = frame[y1:y1+face_h, x1:x2]
            # Pixelar
            if face_region.size > 0:
                face_small = cv2.resize(face_region, (10, 10), interpolation=cv2.INTER_LINEAR)
                face_pixel = cv2.resize(face_small, (x2-x1, face_h), interpolation=cv2.INTER_NEAREST)
                frame[y1:y1+face_h, x1:x2] = face_pixel

        # ---------- DETECTAR MATRÍCULAS ----------
        texto_matricula = ""
        mx1=my1=mx2=my2=conf_m=0.0

        if cls_name in {"car","truck","bus","motorcycle"}:
            crop_vehicle = frame[y1:y2, x1:x2]
            plate_results = model_plates(crop_vehicle, conf=0.22)

            if len(plate_results) and plate_results[0].boxes is not None:
                for p in plate_results[0].boxes:
                    px1,py1,px2,py2 = map(int, p.xyxy[0])
                    mx1, my1, mx2, my2 = x1+px1, y1+py1, x1+px2, y1+py2
                    conf_m = float(p.conf[0])

                    crop_plate = frame[my1:my2, mx1:mx2]
                    crop_plate = cv2.resize(crop_plate, None, fx=3.5, fy=3.5, interpolation=cv2.INTER_CUBIC)
                    crop_plate = cv2.cvtColor(crop_plate, cv2.COLOR_BGR2GRAY)

                    easy_res = easy.readtext(crop_plate, detail=0)
                    texto_matricula = easy_res[0] if len(easy_res)>0 else ""

                    cv2.rectangle(frame, (mx1,my1),(mx2,my2),(0,255,255),2)
                    cv2.putText(frame, texto_matricula, (mx1, max(20,my1-6)),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.7,(0,255,255),2)

        # ---------- ESCRIBIR CSV ----------
        writer.writerow([
            frame_n, cls_name, round(float(conf),3), int(track_id),
            x1,y1,x2,y2,
            round(float(conf_m),3), mx1,my1,mx2,my2, texto_matricula
        ])

    # ---------- MOSTRAR CONTEO ----------
    y = 30
    for k in ["person","car","truck","motorcycle","bus"]:
        cv2.putText(frame, f"{k}: {counts[k]}", (10, y),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,255,0), 2)
        y += 28

    out.write(frame)
    frame_n += 1

cap.release()
out.release()
csv_file.close()

print("Vídeo exportado: resultado_final.mp4")
print("CSV exportado: detecciones_tracking.csv")
print("Conteo único final:", {k: len(v) for k,v in seen_ids.items()})
print("Totales (mismo valor):", counts)
# Out:
# 0: 384x640 3 cars, 1 bus, 1 bench, 218.4ms
# Speed: 10.2ms preprocess, 218.4ms inference, 27.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 142.4ms
# Speed: 7.6ms preprocess, 142.4ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 704x960 (no detections), 159.0ms
# Speed: 5.9ms preprocess, 159.0ms inference, 1.2ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 608x960 (no detections), 168.0ms
# Speed: 5.6ms preprocess, 168.0ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 672x960 (no detections), 142.7ms
# Speed: 7.0ms preprocess, 142.7ms inference, 1.0ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 3 cars, 1 bus, 1 bench, 22.6ms
# Speed: 3.8ms preprocess, 22.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 28.3ms
# Speed: 7.0ms preprocess, 28.3ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 704x960 (no detections), 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 608x960 (no detections), 21.2ms
# Speed: 4.6ms preprocess, 21.2ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 672x960 (no detections), 22.2ms
# Speed: 5.0ms preprocess, 22.2ms inference, 1.1ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 3 cars, 1 bus, 1 bench, 22.5ms
# Speed: 3.2ms preprocess, 22.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 28.1ms
# Speed: 7.1ms preprocess, 28.1ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 672x960 (no detections), 22.1ms
# Speed: 7.2ms preprocess, 22.1ms inference, 1.1ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 608x960 (no detections), 21.0ms
# Speed: 5.2ms preprocess, 21.0ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 704x960 (no detections), 26.4ms
# Speed: 5.5ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 bench, 20.0ms
# Speed: 2.8ms preprocess, 20.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 1 License-Plate, 28.8ms
# Speed: 8.3ms preprocess, 28.8ms inference, 3.7ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 672x960 (no detections), 22.4ms
# Speed: 7.1ms preprocess, 22.4ms inference, 1.2ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 608x960 (no detections), 28.4ms
# Speed: 8.2ms preprocess, 28.4ms inference, 1.7ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 672x960 (no detections), 28.3ms
# Speed: 8.3ms preprocess, 28.3ms inference, 1.2ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 bench, 21.3ms
# Speed: 2.9ms preprocess, 21.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 1 License-Plate, 28.4ms
# Speed: 7.7ms preprocess, 28.4ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 704x960 (no detections), 27.2ms
# Speed: 6.5ms preprocess, 27.2ms inference, 2.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 608x960 (no detections), 27.0ms
# Speed: 5.6ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 672x960 (no detections), 24.6ms
# Speed: 6.3ms preprocess, 24.6ms inference, 1.1ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 bench, 28.4ms
# Speed: 3.9ms preprocess, 28.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 1 License-Plate, 127.7ms
# Speed: 7.4ms preprocess, 127.7ms inference, 2.2ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 672x960 (no detections), 22.2ms
# Speed: 5.5ms preprocess, 22.2ms inference, 0.9ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 608x960 (no detections), 21.5ms
# Speed: 5.0ms preprocess, 21.5ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 640x960 (no detections), 131.3ms
# Speed: 4.9ms preprocess, 131.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 bench, 22.2ms
# Speed: 3.7ms preprocess, 22.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 1 License-Plate, 26.6ms
# Speed: 6.8ms preprocess, 26.6ms inference, 2.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 704x960 (no detections), 26.3ms
# Speed: 5.6ms preprocess, 26.3ms inference, 1.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 576x960 (no detections), 152.7ms
# Speed: 5.4ms preprocess, 152.7ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 960)
#
# 0: 672x960 (no detections), 25.7ms
# Speed: 6.2ms preprocess, 25.7ms inference, 1.3ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 bench, 27.2ms
# Speed: 3.5ms preprocess, 27.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 1 License-Plate, 27.2ms
# Speed: 7.2ms preprocess, 27.2ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 704x960 (no detections), 27.9ms
# Speed: 5.9ms preprocess, 27.9ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 672x960 (no detections), 24.9ms
# Speed: 6.1ms preprocess, 24.9ms inference, 1.3ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 23.9ms
# Speed: 3.1ms preprocess, 23.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 1 License-Plate, 28.6ms
# Speed: 7.1ms preprocess, 28.6ms inference, 2.3ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 704x960 (no detections), 26.5ms
# Speed: 6.2ms preprocess, 26.5ms inference, 1.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 608x960 (no detections), 30.5ms
# Speed: 6.0ms preprocess, 30.5ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 32.3ms
# Speed: 2.8ms preprocess, 32.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 1 License-Plate, 27.0ms
# Speed: 8.1ms preprocess, 27.0ms inference, 2.5ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 672x960 (no detections), 50.5ms
# Speed: 6.6ms preprocess, 50.5ms inference, 2.0ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 640x960 (no detections), 27.3ms
# Speed: 6.6ms preprocess, 27.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 23.3ms
# Speed: 3.4ms preprocess, 23.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 2 License-Plates, 131.5ms
# Speed: 7.0ms preprocess, 131.5ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 704x960 (no detections), 25.9ms
# Speed: 6.1ms preprocess, 25.9ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 640x960 (no detections), 22.0ms
# Speed: 4.8ms preprocess, 22.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.9ms
# Speed: 3.6ms preprocess, 20.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 1 License-Plate, 26.5ms
# Speed: 6.9ms preprocess, 26.5ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 704x960 (no detections), 25.9ms
# Speed: 6.3ms preprocess, 25.9ms inference, 1.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 608x960 (no detections), 20.5ms
# Speed: 5.0ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 21.2ms
# Speed: 2.6ms preprocess, 21.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 1 License-Plate, 27.1ms
# Speed: 8.0ms preprocess, 27.1ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 704x960 (no detections), 26.4ms
# Speed: 7.6ms preprocess, 26.4ms inference, 0.9ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 608x960 (no detections), 21.2ms
# Speed: 5.4ms preprocess, 21.2ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.0ms
# Speed: 2.9ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 1 License-Plate, 27.1ms
# Speed: 7.9ms preprocess, 27.1ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 736x960 (no detections), 25.4ms
# Speed: 6.7ms preprocess, 25.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 640x960 (no detections), 22.8ms
# Speed: 6.6ms preprocess, 22.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 bench, 20.5ms
# Speed: 3.4ms preprocess, 20.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 26.3ms
# Speed: 7.1ms preprocess, 26.3ms inference, 16.7ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 736x960 (no detections), 27.0ms
# Speed: 6.5ms preprocess, 27.0ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 640x960 (no detections), 23.8ms
# Speed: 5.5ms preprocess, 23.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 bench, 25.7ms
# Speed: 2.9ms preprocess, 25.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 25.8ms
# Speed: 6.0ms preprocess, 25.8ms inference, 2.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 736x960 (no detections), 26.4ms
# Speed: 6.6ms preprocess, 26.4ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 640x960 (no detections), 22.7ms
# Speed: 5.3ms preprocess, 22.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 bench, 20.2ms
# Speed: 2.7ms preprocess, 20.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 26.0ms
# Speed: 5.9ms preprocess, 26.0ms inference, 2.7ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 704x960 (no detections), 24.5ms
# Speed: 5.8ms preprocess, 24.5ms inference, 1.2ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 608x960 (no detections), 20.7ms
# Speed: 4.8ms preprocess, 20.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 bench, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 32.7ms
# Speed: 8.2ms preprocess, 32.7ms inference, 2.6ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 736x960 (no detections), 26.7ms
# Speed: 6.4ms preprocess, 26.7ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 608x960 (no detections), 21.0ms
# Speed: 5.4ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 bench, 21.3ms
# Speed: 2.9ms preprocess, 21.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 26.0ms
# Speed: 7.2ms preprocess, 26.0ms inference, 2.7ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 736x960 (no detections), 27.7ms
# Speed: 7.4ms preprocess, 27.7ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 640x960 (no detections), 21.8ms
# Speed: 5.5ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 bench, 19.4ms
# Speed: 2.9ms preprocess, 19.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 26.0ms
# Speed: 5.9ms preprocess, 26.0ms inference, 2.5ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 736x960 (no detections), 26.6ms
# Speed: 5.9ms preprocess, 26.6ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 640x960 (no detections), 22.3ms
# Speed: 5.7ms preprocess, 22.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 bench, 22.1ms
# Speed: 2.7ms preprocess, 22.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 25.9ms
# Speed: 8.7ms preprocess, 25.9ms inference, 2.2ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 768x960 (no detections), 28.1ms
# Speed: 8.3ms preprocess, 28.1ms inference, 1.2ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 640x960 (no detections), 27.7ms
# Speed: 6.9ms preprocess, 27.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 bench, 37.4ms
# Speed: 4.1ms preprocess, 37.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 27.2ms
# Speed: 7.0ms preprocess, 27.2ms inference, 2.7ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 768x960 (no detections), 27.1ms
# Speed: 7.2ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 640x960 (no detections), 24.6ms
# Speed: 5.8ms preprocess, 24.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 21.6ms
# Speed: 2.9ms preprocess, 21.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 26.2ms
# Speed: 7.0ms preprocess, 26.2ms inference, 2.5ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 736x960 (no detections), 27.5ms
# Speed: 8.2ms preprocess, 27.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 640x960 (no detections), 24.3ms
# Speed: 6.5ms preprocess, 24.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 2 cars, 1 bus, 26.2ms
# Speed: 3.6ms preprocess, 26.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 25.9ms
# Speed: 7.2ms preprocess, 25.9ms inference, 2.3ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 768x960 (no detections), 31.7ms
# Speed: 9.7ms preprocess, 31.7ms inference, 1.2ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 608x960 (no detections), 27.3ms
# Speed: 6.1ms preprocess, 27.3ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 25.7ms
# Speed: 3.3ms preprocess, 25.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 (no detections), 28.2ms
# Speed: 6.8ms preprocess, 28.2ms inference, 1.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 736x960 (no detections), 27.5ms
# Speed: 7.5ms preprocess, 27.5ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 640x960 (no detections), 28.1ms
# Speed: 6.2ms preprocess, 28.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 30.2ms
# Speed: 3.6ms preprocess, 30.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 (no detections), 26.2ms
# Speed: 6.7ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 768x960 (no detections), 26.5ms
# Speed: 6.9ms preprocess, 26.5ms inference, 0.9ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 608x960 (no detections), 23.1ms
# Speed: 5.0ms preprocess, 23.1ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 24.1ms
# Speed: 3.1ms preprocess, 24.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 27.0ms
# Speed: 6.4ms preprocess, 27.0ms inference, 2.6ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 768x960 (no detections), 26.8ms
# Speed: 6.4ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 576x960 (no detections), 22.8ms
# Speed: 5.7ms preprocess, 22.8ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 22.2ms
# Speed: 3.1ms preprocess, 22.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 (no detections), 26.5ms
# Speed: 6.5ms preprocess, 26.5ms inference, 1.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 768x960 (no detections), 26.7ms
# Speed: 6.4ms preprocess, 26.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 576x960 (no detections), 23.6ms
# Speed: 5.0ms preprocess, 23.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.0ms
# Speed: 2.5ms preprocess, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 26.1ms
# Speed: 5.7ms preprocess, 26.1ms inference, 2.2ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 800x960 (no detections), 28.2ms
# Speed: 6.3ms preprocess, 28.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 576x960 (no detections), 23.0ms
# Speed: 4.8ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 28.3ms
# Speed: 4.2ms preprocess, 28.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 (no detections), 26.7ms
# Speed: 6.8ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 800x960 (no detections), 28.1ms
# Speed: 6.7ms preprocess, 28.1ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 544x960 (no detections), 125.4ms
# Speed: 5.1ms preprocess, 125.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 bench, 18.9ms
# Speed: 2.9ms preprocess, 18.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 1 License-Plate, 26.0ms
# Speed: 5.8ms preprocess, 26.0ms inference, 2.1ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 832x960 (no detections), 133.4ms
# Speed: 7.3ms preprocess, 133.4ms inference, 0.9ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 544x960 (no detections), 20.1ms
# Speed: 4.3ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 19.8ms
# Speed: 2.8ms preprocess, 19.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 (no detections), 25.9ms
# Speed: 7.2ms preprocess, 25.9ms inference, 1.2ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 832x960 (no detections), 28.5ms
# Speed: 6.8ms preprocess, 28.5ms inference, 0.9ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 544x960 (no detections), 20.3ms
# Speed: 4.4ms preprocess, 20.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 (no detections), 26.3ms
# Speed: 5.8ms preprocess, 26.3ms inference, 0.9ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 832x960 (no detections), 28.8ms
# Speed: 7.2ms preprocess, 28.8ms inference, 1.0ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 576x960 (no detections), 21.8ms
# Speed: 4.4ms preprocess, 21.8ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 23.4ms
# Speed: 2.8ms preprocess, 23.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 704x960 (no detections), 26.2ms
# Speed: 6.3ms preprocess, 26.2ms inference, 0.9ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 832x960 (no detections), 29.0ms
# Speed: 6.9ms preprocess, 29.0ms inference, 0.9ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 512x960 (no detections), 126.0ms
# Speed: 4.2ms preprocess, 126.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 19.0ms
# Speed: 2.6ms preprocess, 19.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 1 License-Plate, 26.8ms
# Speed: 6.8ms preprocess, 26.8ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 864x960 (no detections), 119.4ms
# Speed: 6.3ms preprocess, 119.4ms inference, 1.1ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 544x960 (no detections), 21.3ms
# Speed: 4.7ms preprocess, 21.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.5ms
# Speed: 3.3ms preprocess, 20.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 27.7ms
# Speed: 5.9ms preprocess, 27.7ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 864x960 (no detections), 29.7ms
# Speed: 7.1ms preprocess, 29.7ms inference, 1.0ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 544x960 (no detections), 20.6ms
# Speed: 4.3ms preprocess, 20.6ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 21.2ms
# Speed: 2.6ms preprocess, 21.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 26.6ms
# Speed: 6.2ms preprocess, 26.6ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 864x960 (no detections), 30.7ms
# Speed: 6.7ms preprocess, 30.7ms inference, 1.0ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 544x960 (no detections), 20.6ms
# Speed: 5.1ms preprocess, 20.6ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 21.0ms
# Speed: 2.6ms preprocess, 21.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 1 License-Plate, 27.0ms
# Speed: 7.0ms preprocess, 27.0ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 864x960 (no detections), 30.1ms
# Speed: 6.8ms preprocess, 30.1ms inference, 1.0ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 21.5ms
# Speed: 3.1ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 26.8ms
# Speed: 6.3ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 864x960 (no detections), 29.2ms
# Speed: 6.4ms preprocess, 29.2ms inference, 1.0ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 19.3ms
# Speed: 2.6ms preprocess, 19.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 26.8ms
# Speed: 6.4ms preprocess, 26.8ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 896x960 (no detections), 119.1ms
# Speed: 7.2ms preprocess, 119.1ms inference, 1.1ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 21.1ms
# Speed: 2.9ms preprocess, 21.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 26.5ms
# Speed: 6.0ms preprocess, 26.5ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 896x960 (no detections), 29.0ms
# Speed: 7.5ms preprocess, 29.0ms inference, 1.1ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 20.6ms
# Speed: 2.8ms preprocess, 20.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 1 License-Plate, 26.8ms
# Speed: 6.2ms preprocess, 26.8ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 896x960 (no detections), 29.0ms
# Speed: 7.2ms preprocess, 29.0ms inference, 0.9ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 18.8ms
# Speed: 2.5ms preprocess, 18.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 1 License-Plate, 27.2ms
# Speed: 5.7ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 864x960 (no detections), 30.4ms
# Speed: 6.6ms preprocess, 30.4ms inference, 0.9ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 19.1ms
# Speed: 2.9ms preprocess, 19.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 27.0ms
# Speed: 6.2ms preprocess, 27.0ms inference, 0.9ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 896x960 (no detections), 29.4ms
# Speed: 7.1ms preprocess, 29.4ms inference, 0.9ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 28.8ms
# Speed: 2.5ms preprocess, 28.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 27.2ms
# Speed: 7.5ms preprocess, 27.2ms inference, 0.9ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 896x960 (no detections), 29.5ms
# Speed: 7.9ms preprocess, 29.5ms inference, 0.9ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.6ms
# Speed: 2.5ms preprocess, 20.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 27.1ms
# Speed: 6.5ms preprocess, 27.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 896x960 (no detections), 29.1ms
# Speed: 6.9ms preprocess, 29.1ms inference, 0.9ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 576x960 (no detections), 21.6ms
# Speed: 4.5ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.5ms
# Speed: 2.7ms preprocess, 20.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 1 License-Plate, 26.9ms
# Speed: 6.6ms preprocess, 26.9ms inference, 2.3ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 896x960 (no detections), 29.3ms
# Speed: 7.2ms preprocess, 29.3ms inference, 1.1ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 576x960 (no detections), 22.4ms
# Speed: 4.4ms preprocess, 22.4ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 19.9ms
# Speed: 3.0ms preprocess, 19.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 27.1ms
# Speed: 6.3ms preprocess, 27.1ms inference, 0.9ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 928x960 (no detections), 131.6ms
# Speed: 8.1ms preprocess, 131.6ms inference, 1.1ms postprocess per image at shape (1, 3, 928, 960)
#
# 0: 576x960 (no detections), 21.8ms
# Speed: 4.8ms preprocess, 21.8ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 22.5ms
# Speed: 2.7ms preprocess, 22.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 27.1ms
# Speed: 6.4ms preprocess, 27.1ms inference, 0.9ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x960 (no detections), 31.0ms
# Speed: 8.8ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 608x960 (no detections), 20.8ms
# Speed: 5.2ms preprocess, 20.8ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.7ms
# Speed: 2.9ms preprocess, 20.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 26.9ms
# Speed: 6.4ms preprocess, 26.9ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x960 (no detections), 31.1ms
# Speed: 7.2ms preprocess, 31.1ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 608x960 (no detections), 20.9ms
# Speed: 5.2ms preprocess, 20.9ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.2ms
# Speed: 2.8ms preprocess, 20.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 27.5ms
# Speed: 6.4ms preprocess, 27.5ms inference, 1.3ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x960 (no detections), 31.4ms
# Speed: 8.0ms preprocess, 31.4ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 640x960 (no detections), 22.5ms
# Speed: 5.2ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 21.0ms
# Speed: 2.7ms preprocess, 21.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 26.9ms
# Speed: 6.1ms preprocess, 26.9ms inference, 0.9ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x960 (no detections), 32.2ms
# Speed: 7.3ms preprocess, 32.2ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 608x960 (no detections), 21.3ms
# Speed: 5.0ms preprocess, 21.3ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 42.3ms
# Speed: 3.3ms preprocess, 42.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 29.9ms
# Speed: 6.6ms preprocess, 29.9ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 928x960 (no detections), 30.9ms
# Speed: 7.0ms preprocess, 30.9ms inference, 1.4ms postprocess per image at shape (1, 3, 928, 960)
#
# 0: 640x960 (no detections), 22.3ms
# Speed: 4.9ms preprocess, 22.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 18.8ms
# Speed: 2.5ms preprocess, 18.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 28.5ms
# Speed: 6.3ms preprocess, 28.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 928x960 (no detections), 30.9ms
# Speed: 7.0ms preprocess, 30.9ms inference, 0.9ms postprocess per image at shape (1, 3, 928, 960)
#
# 0: 640x960 (no detections), 22.3ms
# Speed: 5.0ms preprocess, 22.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 18.8ms
# Speed: 2.6ms preprocess, 18.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 28.6ms
# Speed: 6.3ms preprocess, 28.6ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 960x960 (no detections), 31.2ms
# Speed: 8.0ms preprocess, 31.2ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 640x960 (no detections), 22.2ms
# Speed: 5.2ms preprocess, 22.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 19.3ms
# Speed: 2.6ms preprocess, 19.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 28.5ms
# Speed: 6.5ms preprocess, 28.5ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 640x960 (no detections), 22.4ms
# Speed: 4.8ms preprocess, 22.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 26.2ms
# Speed: 2.5ms preprocess, 26.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 28.8ms
# Speed: 6.9ms preprocess, 28.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 640x960 (no detections), 30.5ms
# Speed: 6.1ms preprocess, 30.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 22.5ms
# Speed: 2.7ms preprocess, 22.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 50.1ms
# Speed: 10.9ms preprocess, 50.1ms inference, 0.9ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 640x960 (no detections), 22.2ms
# Speed: 5.6ms preprocess, 22.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 20.3ms
# Speed: 2.5ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 28.6ms
# Speed: 7.1ms preprocess, 28.6ms inference, 1.0ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 640x960 (no detections), 22.3ms
# Speed: 5.3ms preprocess, 22.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 18.5ms
# Speed: 2.7ms preprocess, 18.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 28.7ms
# Speed: 8.0ms preprocess, 28.7ms inference, 1.0ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 640x960 (no detections), 22.3ms
# Speed: 4.9ms preprocess, 22.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 20.9ms
# Speed: 2.5ms preprocess, 20.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 28.6ms
# Speed: 6.6ms preprocess, 28.6ms inference, 0.9ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 672x960 (no detections), 22.5ms
# Speed: 5.3ms preprocess, 22.5ms inference, 0.9ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 19.3ms
# Speed: 2.7ms preprocess, 19.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 28.7ms
# Speed: 6.2ms preprocess, 28.7ms inference, 0.9ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 640x960 (no detections), 22.4ms
# Speed: 6.6ms preprocess, 22.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 19.1ms
# Speed: 2.6ms preprocess, 19.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 28.7ms
# Speed: 6.8ms preprocess, 28.7ms inference, 1.1ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 640x960 (no detections), 22.4ms
# Speed: 4.9ms preprocess, 22.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.8ms
# Speed: 3.1ms preprocess, 20.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 29.1ms
# Speed: 6.9ms preprocess, 29.1ms inference, 1.1ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 640x960 (no detections), 22.1ms
# Speed: 5.4ms preprocess, 22.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 960x960 (no detections), 31.8ms
# Speed: 7.8ms preprocess, 31.8ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 19.8ms
# Speed: 2.6ms preprocess, 19.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 864x960 (no detections), 29.7ms
# Speed: 6.6ms preprocess, 29.7ms inference, 0.9ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 640x960 (no detections), 22.2ms
# Speed: 5.1ms preprocess, 22.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 960x960 (no detections), 31.4ms
# Speed: 8.0ms preprocess, 31.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.4ms
# Speed: 2.6ms preprocess, 20.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 864x960 (no detections), 29.9ms
# Speed: 7.0ms preprocess, 29.9ms inference, 1.1ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 640x960 (no detections), 23.2ms
# Speed: 5.1ms preprocess, 23.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 960x960 (no detections), 31.0ms
# Speed: 7.9ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 30.2ms
# Speed: 2.5ms preprocess, 30.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 864x960 (no detections), 31.7ms
# Speed: 7.0ms preprocess, 31.7ms inference, 1.0ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 608x960 (no detections), 21.0ms
# Speed: 5.6ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 960x960 (no detections), 31.1ms
# Speed: 8.5ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 27.3ms
# Speed: 2.8ms preprocess, 27.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 864x960 (no detections), 30.4ms
# Speed: 7.3ms preprocess, 30.4ms inference, 1.1ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 608x960 (no detections), 28.5ms
# Speed: 5.6ms preprocess, 28.5ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 960x960 (no detections), 31.8ms
# Speed: 8.4ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 32.2ms
# Speed: 3.2ms preprocess, 32.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 864x960 (no detections), 30.6ms
# Speed: 7.9ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 608x960 (no detections), 26.9ms
# Speed: 5.2ms preprocess, 26.9ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 960)
#
# 0: 960x928 (no detections), 139.4ms
# Speed: 8.0ms preprocess, 139.4ms inference, 1.2ms postprocess per image at shape (1, 3, 960, 928)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 32.3ms
# Speed: 4.5ms preprocess, 32.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 864x960 (no detections), 30.6ms
# Speed: 7.3ms preprocess, 30.6ms inference, 1.3ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 960x960 (no detections), 31.7ms
# Speed: 7.9ms preprocess, 31.7ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 25.7ms
# Speed: 2.9ms preprocess, 25.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 864x960 (no detections), 30.0ms
# Speed: 8.0ms preprocess, 30.0ms inference, 1.1ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 960x960 (no detections), 31.3ms
# Speed: 7.8ms preprocess, 31.3ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 25.7ms
# Speed: 3.1ms preprocess, 25.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 864x960 (no detections), 30.4ms
# Speed: 7.6ms preprocess, 30.4ms inference, 1.3ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 960x960 (no detections), 31.5ms
# Speed: 8.1ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 32.8ms
# Speed: 3.2ms preprocess, 32.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.9ms
# Speed: 8.6ms preprocess, 29.9ms inference, 1.2ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x960 (no detections), 34.1ms
# Speed: 7.6ms preprocess, 34.1ms inference, 2.3ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 35.1ms
# Speed: 3.2ms preprocess, 35.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 30.8ms
# Speed: 7.6ms preprocess, 30.8ms inference, 1.3ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x960 (no detections), 31.4ms
# Speed: 10.5ms preprocess, 31.4ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 28.8ms
# Speed: 2.9ms preprocess, 28.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 30.3ms
# Speed: 8.7ms preprocess, 30.3ms inference, 1.5ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x960 (no detections), 32.1ms
# Speed: 8.0ms preprocess, 32.1ms inference, 1.2ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 43.7ms
# Speed: 4.1ms preprocess, 43.7ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 59.4ms
# Speed: 9.4ms preprocess, 59.4ms inference, 2.1ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x960 (no detections), 45.1ms
# Speed: 10.2ms preprocess, 45.1ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 29.4ms
# Speed: 4.1ms preprocess, 29.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.7ms
# Speed: 8.5ms preprocess, 29.7ms inference, 1.2ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x960 (no detections), 31.3ms
# Speed: 8.2ms preprocess, 31.3ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 25.9ms
# Speed: 2.9ms preprocess, 25.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.3ms
# Speed: 14.7ms preprocess, 29.3ms inference, 1.1ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x960 (no detections), 32.7ms
# Speed: 8.0ms preprocess, 32.7ms inference, 2.1ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 31.2ms
# Speed: 3.1ms preprocess, 31.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 30.0ms
# Speed: 9.3ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x960 (no detections), 31.2ms
# Speed: 9.2ms preprocess, 31.2ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 29.4ms
# Speed: 3.2ms preprocess, 29.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.2ms
# Speed: 9.4ms preprocess, 29.2ms inference, 1.3ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x960 (no detections), 31.9ms
# Speed: 8.9ms preprocess, 31.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 22.5ms
# Speed: 2.9ms preprocess, 22.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.3ms
# Speed: 8.7ms preprocess, 29.3ms inference, 0.9ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x960 (no detections), 31.4ms
# Speed: 9.0ms preprocess, 31.4ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 28.9ms
# Speed: 2.7ms preprocess, 28.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.9ms
# Speed: 10.8ms preprocess, 29.9ms inference, 1.2ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x928 (no detections), 32.0ms
# Speed: 9.7ms preprocess, 32.0ms inference, 1.2ms postprocess per image at shape (1, 3, 960, 928)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.5ms
# Speed: 9.3ms preprocess, 29.5ms inference, 1.0ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x960 (no detections), 31.5ms
# Speed: 8.7ms preprocess, 31.5ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 28.9ms
# Speed: 2.7ms preprocess, 28.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.3ms
# Speed: 9.7ms preprocess, 29.3ms inference, 0.9ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x928 (no detections), 31.2ms
# Speed: 9.6ms preprocess, 31.2ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 928)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 28.1ms
# Speed: 3.2ms preprocess, 28.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 30.2ms
# Speed: 10.0ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x896 (no detections), 141.7ms
# Speed: 9.3ms preprocess, 141.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 896)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 24.7ms
# Speed: 3.6ms preprocess, 24.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.3ms
# Speed: 10.2ms preprocess, 29.3ms inference, 1.0ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x896 (no detections), 29.8ms
# Speed: 8.5ms preprocess, 29.8ms inference, 1.2ms postprocess per image at shape (1, 3, 960, 896)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 22.2ms
# Speed: 3.0ms preprocess, 22.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 32.8ms
# Speed: 12.7ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x928 (no detections), 37.5ms
# Speed: 11.3ms preprocess, 37.5ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 928)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 34.2ms
# Speed: 3.3ms preprocess, 34.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.4ms
# Speed: 12.2ms preprocess, 29.4ms inference, 0.9ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x928 (no detections), 31.1ms
# Speed: 9.0ms preprocess, 31.1ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 928)
#
# 0: 384x640 1 car, 1 bus, 1 bench, 29.4ms
# Speed: 2.8ms preprocess, 29.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 896x960 (no detections), 29.4ms
# Speed: 9.7ms preprocess, 29.4ms inference, 1.0ms postprocess per image at shape (1, 3, 896, 960)
#
# 0: 960x896 (no detections), 29.7ms
# Speed: 9.1ms preprocess, 29.7ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 896)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 29.4ms
# Speed: 2.9ms preprocess, 29.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 928x960 (no detections), 31.3ms
# Speed: 9.6ms preprocess, 31.3ms inference, 1.1ms postprocess per image at shape (1, 3, 928, 960)
#
# 0: 960x896 (no detections), 37.3ms
# Speed: 9.3ms preprocess, 37.3ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 896)
#
# 0: 960x832 (no detections), 130.3ms
# Speed: 9.4ms preprocess, 130.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 832)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 21.0ms
# Speed: 3.2ms preprocess, 21.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 928x960 (no detections), 30.8ms
# Speed: 10.1ms preprocess, 30.8ms inference, 0.9ms postprocess per image at shape (1, 3, 928, 960)
#
# 0: 960x928 (no detections), 30.8ms
# Speed: 8.6ms preprocess, 30.8ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 928)
#
# 0: 960x832 (no detections), 28.8ms
# Speed: 8.8ms preprocess, 28.8ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 832)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.5ms
# Speed: 2.9ms preprocess, 20.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 928x960 (no detections), 30.7ms
# Speed: 9.6ms preprocess, 30.7ms inference, 1.0ms postprocess per image at shape (1, 3, 928, 960)
#
# 0: 960x896 (no detections), 30.2ms
# Speed: 9.5ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 896)
#
# 0: 960x832 (no detections), 28.6ms
# Speed: 8.2ms preprocess, 28.6ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 832)
#
# 0: 384x640 2 cars, 1 bus, 1 bench, 20.2ms
# Speed: 3.2ms preprocess, 20.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 928x960 (no detections), 31.1ms
# Speed: 9.5ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 928, 960)
#
# 0: 960x864 (no detections), 124.8ms
# Speed: 8.1ms preprocess, 124.8ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 864)
#
# 0: 960x832 (no detections), 29.3ms
# Speed: 9.4ms preprocess, 29.3ms inference, 1.2ms postprocess per image at shape (1, 3, 960, 832)
#
# 0: 384x640 2 cars, 1 bus, 22.4ms
# Speed: 3.5ms preprocess, 22.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 928x960 (no detections), 31.1ms
# Speed: 9.6ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 928, 960)
#
# 0: 960x896 (no detections), 30.3ms
# Speed: 9.6ms preprocess, 30.3ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 896)
#
# 0: 960x832 (no detections), 29.0ms
# Speed: 9.2ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 832)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 22.5ms
# Speed: 2.9ms preprocess, 22.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 928x960 (no detections), 31.2ms
# Speed: 9.7ms preprocess, 31.2ms inference, 1.0ms postprocess per image at shape (1, 3, 928, 960)
#
# 0: 960x864 (no detections), 30.0ms
# Speed: 9.2ms preprocess, 30.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 864)
#
# 0: 960x832 (no detections), 29.1ms
# Speed: 9.3ms preprocess, 29.1ms inference, 1.7ms postprocess per image at shape (1, 3, 960, 832)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 25.4ms
# Speed: 3.3ms preprocess, 25.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 960x960 (no detections), 31.9ms
# Speed: 9.3ms preprocess, 31.9ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 960)
#
# 0: 960x928 (no detections), 31.4ms
# Speed: 9.9ms preprocess, 31.4ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 928)
#
# 0: 960x864 (no detections), 30.6ms
# ...
# Speed: 8.5ms preprocess, 34.7ms inference, 1.6ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 45.9ms
# Speed: 4.6ms preprocess, 45.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 33.8ms
# Speed: 8.9ms preprocess, 33.8ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 736x960 (no detections), 43.3ms
# Speed: 10.1ms preprocess, 43.3ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 41.1ms
# Speed: 12.0ms preprocess, 41.1ms inference, 1.7ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 19.2ms
# Speed: 2.8ms preprocess, 19.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 37.1ms
# Speed: 7.2ms preprocess, 37.1ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 736x960 (no detections), 74.1ms
# Speed: 9.6ms preprocess, 74.1ms inference, 4.7ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 41.5ms
# Speed: 8.3ms preprocess, 41.5ms inference, 1.6ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 52.9ms
# Speed: 4.6ms preprocess, 52.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 51.9ms
# Speed: 11.0ms preprocess, 51.9ms inference, 2.3ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 736x960 (no detections), 64.2ms
# Speed: 12.9ms preprocess, 64.2ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 45.5ms
# Speed: 40.8ms preprocess, 45.5ms inference, 2.1ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 40.3ms
# Speed: 3.4ms preprocess, 40.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 48.0ms
# Speed: 11.3ms preprocess, 48.0ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 736x960 (no detections), 46.5ms
# Speed: 9.9ms preprocess, 46.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 43.9ms
# Speed: 8.8ms preprocess, 43.9ms inference, 1.8ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 35.4ms
# Speed: 2.9ms preprocess, 35.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 24.1ms
# Speed: 7.1ms preprocess, 24.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 736x960 (no detections), 42.4ms
# Speed: 9.6ms preprocess, 42.4ms inference, 2.8ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 26.5ms
# Speed: 6.6ms preprocess, 26.5ms inference, 1.2ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 47.4ms
# Speed: 4.8ms preprocess, 47.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 67.9ms
# Speed: 11.0ms preprocess, 67.9ms inference, 2.3ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 736x960 (no detections), 51.4ms
# Speed: 8.7ms preprocess, 51.4ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 83.0ms
# Speed: 11.6ms preprocess, 83.0ms inference, 2.4ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 37.0ms
# Speed: 4.1ms preprocess, 37.0ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 27.9ms
# Speed: 6.9ms preprocess, 27.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 704x960 (no detections), 26.3ms
# Speed: 7.0ms preprocess, 26.3ms inference, 1.7ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 672x960 (no detections), 22.9ms
# Speed: 6.3ms preprocess, 22.9ms inference, 1.3ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 67.7ms
# Speed: 5.4ms preprocess, 67.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x960 (no detections), 28.1ms
# Speed: 6.3ms preprocess, 28.1ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 960)
#
# 0: 704x960 (no detections), 26.4ms
# Speed: 6.6ms preprocess, 26.4ms inference, 1.6ms postprocess per image at shape (1, 3, 704, 960)
#
# 0: 672x960 (no detections), 21.5ms
# Speed: 6.5ms preprocess, 21.5ms inference, 1.1ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 38.4ms
# Speed: 3.9ms preprocess, 38.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 27.6ms
# Speed: 7.3ms preprocess, 27.6ms inference, 0.9ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 736x960 (no detections), 26.5ms
# Speed: 7.1ms preprocess, 26.5ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 25.5ms
# Speed: 7.6ms preprocess, 25.5ms inference, 7.5ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 47.4ms
# Speed: 3.8ms preprocess, 47.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 65.0ms
# Speed: 8.3ms preprocess, 65.0ms inference, 2.1ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 736x960 (no detections), 32.8ms
# Speed: 9.7ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 60.1ms
# Speed: 8.7ms preprocess, 60.1ms inference, 1.6ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 33.1ms
# Speed: 3.0ms preprocess, 33.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 27.7ms
# Speed: 6.7ms preprocess, 27.7ms inference, 0.9ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 736x960 (no detections), 26.0ms
# Speed: 8.3ms preprocess, 26.0ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 42.0ms
# Speed: 8.3ms preprocess, 42.0ms inference, 1.6ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 33.3ms
# Speed: 2.9ms preprocess, 33.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 27.4ms
# Speed: 9.3ms preprocess, 27.4ms inference, 0.8ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 736x960 (no detections), 27.3ms
# Speed: 5.4ms preprocess, 27.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 36.2ms
# Speed: 7.6ms preprocess, 36.2ms inference, 1.5ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 32.8ms
# Speed: 4.1ms preprocess, 32.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 29.3ms
# Speed: 9.0ms preprocess, 29.3ms inference, 2.0ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 768x960 (no detections), 26.0ms
# Speed: 6.6ms preprocess, 26.0ms inference, 1.7ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 672x960 (no detections), 37.3ms
# Speed: 10.4ms preprocess, 37.3ms inference, 2.1ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 33.4ms
# Speed: 3.7ms preprocess, 33.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 832x960 (no detections), 38.4ms
# Speed: 9.8ms preprocess, 38.4ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 960)
#
# 0: 736x960 (no detections), 46.8ms
# Speed: 11.8ms preprocess, 46.8ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 26.6ms
# Speed: 5.5ms preprocess, 26.6ms inference, 1.1ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 22.5ms
# Speed: 2.7ms preprocess, 22.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 864x960 (no detections), 28.1ms
# Speed: 9.6ms preprocess, 28.1ms inference, 0.9ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 736x960 (no detections), 25.3ms
# Speed: 6.5ms preprocess, 25.3ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 19.8ms
# Speed: 5.4ms preprocess, 19.8ms inference, 1.1ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 3 cars, 1 bench, 33.2ms
# Speed: 4.1ms preprocess, 33.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 864x960 (no detections), 26.7ms
# Speed: 8.3ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 864, 960)
#
# 0: 768x960 (no detections), 24.4ms
# Speed: 6.2ms preprocess, 24.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 672x960 (no detections), 19.7ms
# Speed: 6.7ms preprocess, 19.7ms inference, 0.8ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 32.2ms
# Speed: 2.8ms preprocess, 32.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 30.8ms
# Speed: 6.8ms preprocess, 30.8ms inference, 8.0ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 33.4ms
# Speed: 9.3ms preprocess, 33.4ms inference, 1.4ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 24.1ms
# Speed: 3.8ms preprocess, 24.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 25.2ms
# Speed: 6.6ms preprocess, 25.2ms inference, 1.2ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 672x960 (no detections), 36.1ms
# Speed: 6.8ms preprocess, 36.1ms inference, 1.6ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 28.5ms
# Speed: 2.5ms preprocess, 28.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 23.5ms
# Speed: 6.9ms preprocess, 23.5ms inference, 1.1ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 672x960 (no detections), 24.1ms
# Speed: 6.0ms preprocess, 24.1ms inference, 1.2ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 25.7ms
# Speed: 2.7ms preprocess, 25.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 23.6ms
# Speed: 5.5ms preprocess, 23.6ms inference, 0.8ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 640x960 (no detections), 58.0ms
# Speed: 6.9ms preprocess, 58.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 25.1ms
# Speed: 3.0ms preprocess, 25.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 24.5ms
# Speed: 7.6ms preprocess, 24.5ms inference, 1.2ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 672x960 (no detections), 21.2ms
# Speed: 7.9ms preprocess, 21.2ms inference, 1.4ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 29.6ms
# Speed: 3.9ms preprocess, 29.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 24.9ms
# Speed: 6.2ms preprocess, 24.9ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 28.2ms
# Speed: 6.1ms preprocess, 28.2ms inference, 1.2ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 45.9ms
# Speed: 4.6ms preprocess, 45.9ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 27.0ms
# Speed: 8.3ms preprocess, 27.0ms inference, 1.1ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 672x960 (no detections), 19.7ms
# Speed: 6.5ms preprocess, 19.7ms inference, 1.0ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 40.2ms
# Speed: 3.1ms preprocess, 40.2ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 34.9ms
# Speed: 7.2ms preprocess, 34.9ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 41.5ms
# Speed: 7.8ms preprocess, 41.5ms inference, 1.7ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 48.6ms
# Speed: 3.9ms preprocess, 48.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 23.6ms
# Speed: 9.0ms preprocess, 23.6ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 20.1ms
# Speed: 5.7ms preprocess, 20.1ms inference, 0.9ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 19.1ms
# Speed: 2.5ms preprocess, 19.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 24.3ms
# Speed: 7.1ms preprocess, 24.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 32.7ms
# Speed: 6.7ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 30.2ms
# Speed: 3.0ms preprocess, 30.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 27.6ms
# Speed: 7.8ms preprocess, 27.6ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 42.9ms
# Speed: 10.0ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 44.7ms
# Speed: 3.9ms preprocess, 44.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 768x960 (no detections), 64.9ms
# Speed: 9.1ms preprocess, 64.9ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 672x960 (no detections), 31.5ms
# Speed: 7.6ms preprocess, 31.5ms inference, 1.7ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 26.4ms
# Speed: 3.0ms preprocess, 26.4ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 40.5ms
# Speed: 8.4ms preprocess, 40.5ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 25.6ms
# Speed: 7.7ms preprocess, 25.6ms inference, 1.6ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 23.0ms
# Speed: 3.5ms preprocess, 23.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 47.8ms
# Speed: 10.2ms preprocess, 47.8ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 31.3ms
# Speed: 8.2ms preprocess, 31.3ms inference, 1.3ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 33.1ms
# Speed: 4.4ms preprocess, 33.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 28.5ms
# Speed: 7.7ms preprocess, 28.5ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 23.3ms
# Speed: 8.4ms preprocess, 23.3ms inference, 0.9ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 29.8ms
# Speed: 3.6ms preprocess, 29.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 30.9ms
# Speed: 7.1ms preprocess, 30.9ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 81.1ms
# Speed: 10.0ms preprocess, 81.1ms inference, 2.6ms postprocess per image at shape (1, 3, 672, 960)
#
# 0: 384x640 1 person, 2 cars, 1 bench, 53.5ms
# Speed: 4.8ms preprocess, 53.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 736x960 (no detections), 59.5ms
# Speed: 10.9ms preprocess, 59.5ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 960)
#
# 0: 672x960 (no detections), 35.9ms
# Speed: 7.1ms preprocess, 35.9ms inference, 1.4ms postprocess per image at shape (1, 3, 672, 960)
# Vídeo exportado: resultado_final.mp4
# CSV exportado: detecciones_tracking.csv
# Conteo único final: {'bus': 1, 'car': 100, 'motorcycle': 3, 'truck': 16, 'person': 29}
# Totales (mismo valor): {'bus': 1, 'car': 100, 'motorcycle': 3, 'truck': 16, 'person': 29}

# %%
# Ruta del ejecutable tesseract (ajústala si es diferente)
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# OCRs
easy = easyocr.Reader(['en', 'es'])

# Carpeta con las imágenes
input_folder = "Comparativa/"

# CSV donde pondrás las matrículas reales
ground_truth_file = "matriculas_reales.csv"

# CSV donde guardaremos los resultados
output_file = "comparativa_ocr_imgs.csv"

# Leer matrícula real por imagen
gt = {}
with open(ground_truth_file, "r") as f:
    reader = csv.reader(f)
    next(reader)
    for fila in reader:
        imagen, matricula = fila
        gt[imagen] = matricula.strip().upper()

# Crear CSV de resultados
with open(output_file, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["imagen", "matricula_real", "easyocr", "tesseract",
                     "acierto_easyocr", "acierto_tesseract",
                     "tiempo_easyocr(ms)", "tiempo_tesseract(ms)"])

    for img_name in os.listdir(input_folder):

        path = os.path.join(input_folder, img_name)
        img = cv2.imread(path)

        # EASYOCR
        t0 = time.time()
        easy_res = easy.readtext(img)
        easy_text = easy_res[0][-2].replace(" ", "") if easy_res else ""
        easy_time = (time.time() - t0) * 1000

        # TESSERACT
        t1 = time.time()
        tess_text = pytesseract.image_to_string(img).strip().replace("\n", "").replace(" ", "")
        tess_time = (time.time() - t1) * 1000

        # Normalizar
        easy_text = easy_text.upper()
        tess_text = tess_text.upper()
        real = gt[img_name]

        # Comparaciones exactas
        acierto_easy = 1 if real == easy_text else 0
        acierto_tess = 1 if real == tess_text else 0

        # Guardar fila
        writer.writerow([img_name, real, easy_text, tess_text,
                         acierto_easy, acierto_tess,
                         round(easy_time), round(tess_time)])

print("Comparativa terminada. Archivo guardado en:", output_file)
# Out:
# Comparativa terminada. Archivo guardado en: comparativa_ocr_imgs.csv
